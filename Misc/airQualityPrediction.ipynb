# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/FA21 CMPE 255 Term Project/PM2.5/daily_88101_2001.csv", encoding="utf8")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #Make sure to add a shortcut to the shared folder in your own drive before running

# %%
df.head(3)
# Out:
#   State Code  County Code  ...                  CBSA Name  Date of Last Change
# 0          1            3  ...  Daphne-Fairhope-Foley, AL           2015-04-02
# 1          1            3  ...  Daphne-Fairhope-Foley, AL           2015-04-02
# 2          1            3  ...  Daphne-Fairhope-Foley, AL           2015-04-02
#
# [3 rows x 29 columns]

# %% [markdown]
# PM 2.5: Need to only average for arithmetic mean and AQI

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166081 entries, 0 to 166080
# Data columns (total 29 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   State Code           166081 non-null  object
#  1   County Code          166081 non-null  int64
#  2   Site Num             166081 non-null  int64
#  3   Parameter Code       166081 non-null  int64
#  4   POC                  166081 non-null  int64
#  5   Latitude             166081 non-null  float64
#  6   Longitude            166081 non-null  float64
#  7   Datum                166081 non-null  object
#  8   Parameter Name       166081 non-null  object
#  9   Sample Duration      166081 non-null  object
#  10  Pollutant Standard   166081 non-null  object
#  11  Date Local           166081 non-null  object
#  12  Units of Measure     166081 non-null  object
#  13  Event Type           166081 non-null  object
#  14  Observation Count    166081 non-null  int64
# ...

# %%
df['Observation Count'].value_counts()
# Out:
# 1    166081
# Name: Observation Count, dtype: int64
